# %%
# !pip3 install tweepy --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 KB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 3.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: tweepy
#     Found existing installation: tweepy 3.10.0
#     Uninstalling tweepy-3.10.0:
#       Successfully uninstalled tweepy-3.10.0
# ...

# %%
import tweepy
import numpy as np
import pandas as pd
from textblob import TextBlob

# %%
#Chave
bearer_token = "AAAAAAAAAAAAAAAAAAAAAGJrlgEAAAAAbwqHxRmdRHG1qqeZTzx7OrESAig%3D4QiKcBbjpuEmOXMRala40QU0D2QSEWEPIVyIRKcjlG29JDgACA"

client = tweepy.Client(bearer_token=bearer_token)

# %%
results = []
resultid = []
resulttext = []

# %%
tweets = tweepy.Paginator(client.search_recent_tweets, query='saquarema', 
                              max_results=100).flatten(limit=1000)

# %%
for tweet in tweepy.Paginator(client.search_recent_tweets, query='saquarema', 
                              max_results=100).flatten(limit=1000):
    #print(tweet.text)
    resultid.append(tweet.id)
    resulttext.append(tweet.text)

# %%
resulttext
# Out:
# ['eu vou, eu vou, pra saquarema eu vou',
#  '@__zrangelz mas num é um lugar praiano rangelzin de saquarema??',
#  '@GMarinnS Acho que vc não conhece o alviverde de saquarema',
#  'o tanto que eu amo saquarema, eu tbm odeio',
#  'Melhor coisa que eu fiz foi vim pra saquarema passar esse final de semana 🙏🕊',
#  'Aproveitar o descanso fora de feriados!\nIsso se chama escolha e planejamento de vida.\nPorque no feriado, eu trabalho! 😉\n\nQual é o sua escolha hoje? Aproveitar somente o hoje ou aproveitar o hoje pensando também no seu futuro?\n#saquarema #beach #praia #empreender #emprendedor https://t.co/IeNn2tTR49',
#  '@dudulttjaks é saquarema best',
#  'me bate uma puta sdds quando eu tô escutando música daí começa a tocar Saquarema e eu fico lembrando quando eu e a nique falava que essa era nossa música e a gente começava a dança igual duas idiotas',
# ...

# %%
import re

# %%
type(resulttext)
# Out:
# list

# %%
resulttext
# Out:
# ['eu vou, eu vou, pra saquarema eu vou',
#  '@__zrangelz mas num é um lugar praiano rangelzin de saquarema??',
#  '@GMarinnS Acho que vc não conhece o alviverde de saquarema',
#  'o tanto que eu amo saquarema, eu tbm odeio',
#  'Melhor coisa que eu fiz foi vim pra saquarema passar esse final de semana 🙏🕊',
#  'Aproveitar o descanso fora de feriados!\nIsso se chama escolha e planejamento de vida.\nPorque no feriado, eu trabalho! 😉\n\nQual é o sua escolha hoje? Aproveitar somente o hoje ou aproveitar o hoje pensando também no seu futuro?\n#saquarema #beach #praia #empreender #emprendedor https://t.co/IeNn2tTR49',
#  '@dudulttjaks é saquarema best',
#  'me bate uma puta sdds quando eu tô escutando música daí começa a tocar Saquarema e eu fico lembrando quando eu e a nique falava que essa era nossa música e a gente começava a dança igual duas idiotas',
# ...

# %%
for tweet in tweets:
    # Removendo menções e links dos tweets
    tweet_text = ' '.join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", tweet.text).split())

# %%
tweet_text
# Out:
# 'Trouxe de Saquarema 2 corvinas gigantes e fil de tilpia pra minha avT toda boba'

# %%
    analysis = TextBlob(tweet_text)
    if analysis.sentiment.polarity > 0:
        sentimento = 'positivo'
    elif analysis.sentiment.polarity == 0:
        sentimento = 'neutro'
    else:
        sentimento = 'negativo'
    
    # Exibindo o texto do tweet e o sentimento detectado
    print(tweet_text)
    print('Sentimento:', sentimento)
# Out:
# Trouxe de Saquarema 2 corvinas gigantes e fil de tilpia pra minha avT toda boba
# Sentimento: neutro
